# %% [markdown]
# # Load State of the Union (SOU) speeches as json

# %%
import json
from pprint import pprint
import re
from pyspark.sql import SparkSession

spark  = SparkSession.builder.master('local').appName('sou').getOrCreate()
speeches = spark.read.json('/project/cmsc25025/sou/speeches.json')
speeches = spark.SparkContext.parallelize(speeches.collect())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-6d99fc07b8ba> in <module>()
#       6 spark  = SparkSession.builder.master('local').appName('sou').getOrCreate()
#       7 speeches = spark.read.json('/project/cmsc25025/sou/speeches.json')
# ----> 8 speeches = spark.SparkContext.parallelize(speeches.collect())
#
# AttributeError: 'SparkSession' object has no attribute 'SparkContext'

# %% [markdown]
# # (a) compute TF-IDF vectors

# %%
import string
from math import log10

num_speeches = speeches.rdd.count()

def sou_word_count(x):
    x = x.replace('Mr.','')\
         .replace('Mrs.','')\
         .replace('Miss.','')\
         .replace('Ms.', '')\
         .replace('Dr.', '')\
         .replace('Prof.','')

    x = x.lower().translate({ord(c): None for c in string.punctuation})
        
    wrds = x.strip().split(' ')
    
    wrd_cnts = {}
    
    for w in wrds:
        wrd_cnts[w] = wrd_cnts.get(w, 0) + 1
    
    return wrd_cnts

def sou_doc_count(*args):
    doc_counts = {}
    
    for d in args:
        for word in d.keys():
            doc_counts[word] = doc_counts.get(word, 0) + 1
        
    return doc_counts

def sou_word_across_doc_count(*args):
    counts = {}
    
    for d in args:
        for word in d.keys():
            counts[word] = counts.get(word, 0) + d[word]
    
    return counts

def compute_weights(wrd_cnts, doc_cnts, all_doc_cnts, top20):
    weights = {}
    
    for word in doc_cnts.keys():
        if all_doc_cnts[word] >= 50 and word not in top20:
            weights[word] = wrd_cnts.get(word, 0) * log10(num_speeches/doc_cnts[word])

    return weights.values()
        
sou_wrd_cnt = speeches.rdd.map(lambda x: (x['year'], x['president'], sou_word_count(x['text'])))

stripped_wrd_cnt = sou_wrd_cnt.map(lambda x: x[2])

sou_doc_cnt = stripped_wrd_cnt.reduce(sou_doc_count)
sou_wrd_acrss_doc_cnt = stripped_wrd_cnt.reduce(sou_word_across_doc_count)
sou_wrd_tpl_lst = sou_wrd_acrss_doc_cnt.items()

top20 = sorted(sou_wrd_tpl_lst, key=lambda x: x[1])[len(sou_wrd_tpl_lst)-20:]

tf_idf_weights = sou_wrd_cnt.map(lambda d: (d[0], d[1], compute_weights(d[2], sou_doc_cnt, sou_wrd_acrss_doc_cnt, top20)))

print tf_idf_weights.collect()[1]
# Out:
# (u'1897', u'William McKinley', [6.15923533045026, 4.10615688696684, 10.2653922174171, 2.05307844348342, 4.7082168782948015, 2.3541084391474008, 6.15923533045026, 4.7082168782948015, 4.10615688696684, 2.05307844348342, 61.592353304502595, 2.05307844348342, 2.05307844348342, 4.7082168782948015, 4.10615688696684, 12.31847066090052, 36.95541198270156, 14.124650634884404, 7.062325317442202, 2.3541084391474008, 4.10615688696684, 2.05307844348342, 8.21231377393368, 2.3541084391474008, 20.5307844348342, 2.05307844348342, 2.05307844348342, 9.416433756589603, 2.05307844348342, 8.21231377393368, 6.15923533045026, 4.10615688696684, 2.3541084391474008, 2.05307844348342, 2.05307844348342, 8.21231377393368, 4.10615688696684, 4.10615688696684, 4.10615688696684, 2.05307844348342, 2.05307844348342, 2.3541084391474008, 4.10615688696684, 12.31847066090052, 2.05307844348342, 2.3541084391474008, 2.05307844348342, 14.37154910438394, 2.05307844348342, 4.10615688696684, 8.21231377393368, 4.10615688696684, 14.124650634884404, 16.42462754786736, 2.05307844348342, 6.15923533045026, 10.2653922174171, 4.10615688696684, 2.3541084391474008, 6.15923533045026, 41.0615688696684, 4.10615688696684, 4.7082168782948015, 18.47770599135078, 4.7082168782948015, 10.2653922174171, 8.21231377393368, 2.05307844348342, 2.3541084391474008, 4.10615688696684, 2.05307844348342, 2.05307844348342, 4.10615688696684, 4.10615688696684, 2.3541084391474008, 30.796176652251297, 8.21231377393368, 2.3541084391474008, 14.37154910438394, 32.84925509573472, 4.10615688696684, 12.31847066090052, 2.05307844348342, 14.37154910438394, 10.2653922174171, 2.3541084391474008, 16.42462754786736, 8.21231377393368, 4.10615688696684, 4.7082168782948015, 2.3541084391474008, 14.37154910438394, 4.10615688696684, 4.10615688696684, 12.31847066090052, 30.796176652251297, 6.15923533045026, 2.05307844348342, 6.15923533045026, 2.05307844348342, 2.05307844348342, 8.21231377393368, 2.3541084391474008, 6.15923533045026, 2.3541084391474008, 14.37154910438394, 6.15923533045026, 7.062325317442202, 2.3541084391474008, 7.062325317442202, 6.15923533045026, 6.15923533045026, 2.05307844348342, 4.7082168782948015, 8.21231377393368, 2.3541084391474008, 28.74309820876788, 2.3541084391474008, 2.05307844348342, 8.21231377393368, 6.15923533045026, 2.3541084391474008, 8.21231377393368, 2.05307844348342, 2.3541084391474008, 22.583862878317618, 28.74309820876788, 4.10615688696684, 2.05307844348342, 2.05307844348342, 2.3541084391474008, 24.63694132180104, 2.05307844348342, 8.21231377393368, 2.3541084391474008, 2.05307844348342, 6.15923533045026, 8.21231377393368, 10.2653922174171, 4.10615688696684, 2.3541084391474008, 2.05307844348342, 6.15923533045026, 4.10615688696684, 4.7082168782948015, 2.05307844348342, 2.05307844348342, 12.31847066090052, 2.3541084391474008, 10.2653922174171, 16.42462754786736, 8.21231377393368, 2.3541084391474008, 6.15923533045026, 6.15923533045026, 2.3541084391474008, 4.7082168782948015, 4.7082168782948015, 22.583862878317618, 10.2653922174171, 2.05307844348342, 2.3541084391474008, 4.10615688696684, 2.05307844348342, 2.05307844348342, 4.10615688696684, 4.10615688696684, 2.3541084391474008, 14.37154910438394, 2.3541084391474008, 10.2653922174171, 6.15923533045026, 24.63694132180104, 2.05307844348342, 2.3541084391474008, 4.10615688696684, 2.3541084391474008, 2.3541084391474008, 4.10615688696684, 4.10615688696684, 6.15923533045026, 2.3541084391474008, 2.05307844348342, 2.05307844348342, 2.3541084391474008, 41.0615688696684, 2.3541084391474008, 10.2653922174171, 2.3541084391474008, 2.3541084391474008, 2.05307844348342, 2.05307844348342, 2.05307844348342, 4.10615688696684, 7.062325317442202, 2.05307844348342, 2.3541084391474008, 6.15923533045026, 2.3541084391474008, 6.15923533045026, 14.124650634884404, 2.05307844348342, 2.3541084391474008, 4.10615688696684, 2.3541084391474008, 53.38003953056892, 2.3541084391474008, 2.05307844348342, 2.3541084391474008, 2.05307844348342, 2.3541084391474008, 2.05307844348342, 2.0 ...

# %% [markdown]
# # (b) similarity between speeches

# %%
import numpy as np
from itertools import combinations

def sim(d,dp):
    norm_d = np.linalg.norm(d)
    norm_dp = np.linalg.norm(dp)
    return np.dot(d,dp) / (norm_d * norm_dp)

all_speeches_only_weights = tf_idf_weights.map(lambda x: x[2])

def same_pres_sim_list(weights):
    #each element is a tuple of [(year, pres), (year, pres), sim]
    sim_list = []
    for c in combinations(weights, 2):
        if c[0][1] == c[1][1]:
            sim_list.append((c[0][:2], c[1][:2], sim(c[0][2],c[1][2])))
    
    return spark.sparkContext.parallelize(sim_list)

def diff_pres_sim_list(weights):
    #each element is a tuple of [(year, pres), (year, pres), sim]
    sim_list = []
    for c in combinations(weights, 2):
        if c[0][1] != c[1][1]:
            sim_list.append((c[0][:2], c[1][:2], sim(c[0][2],c[1][2])))
    
    return spark.sparkContext.parallelize(sim_list)


diff_pres_sim = diff_pres_sim_list(tf_idf_weights.collect()).sortBy(lambda x: x[2])
same_pres_sim = same_pres_sim_list(tf_idf_weights.collect()).sortBy(lambda x: x[2])

print 'Similar pairs given by diff President'
print 2 * ' ' + '  year1' + '   pres1' +'    year2' + '     pres2' + '     sim\n' + 55 * '='

for data in diff_pres_sim.collect()[:50]:
    print '%s\n%s ' % (data, 55 * '-')
# Out:
# Similar pairs given by diff President
#     year1   pres1    year2     pres2     sim
# =======================================================
# ((u'1883', u'Chester A. Arthur'), (u'2001', u'George W. Bush'), 0.70580282652757687)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1882', u'Chester A. Arthur'), 0.7118514263234853)
# -------------------------------------------------------
# ((u'1827', u'John Quincy Adams'), (u'2001', u'George W. Bush'), 0.71464769264806038)
# -------------------------------------------------------
# ((u'1828', u'John Quincy Adams'), (u'2001', u'George W. Bush'), 0.72205350729033468)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1872', u'Ulysses S. Grant'), 0.73070441620277948)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1884', u'Chester A. Arthur'), 0.7345036885452868)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1815', u'James Madison'), 0.73639974107192285)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1881', u'Chester A. Arthur'), 0.7378578950573077)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1855', u'Franklin Pierce'), 0.73825220647371581)
# -------------------------------------------------------
# ((u'1883', u'Chester A. Arthur'), (u'2000', u'William J. Clinton'), 0.73892200425945076)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1825', u'John Quincy Adams'), 0.74123011373757364)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1876', u'Ulysses S. Grant'), 0.74368670421768823)
# -------------------------------------------------------
# ((u'1994', u'William J. Clinton'), (u'1883', u'Chester A. Arthur'), 0.74526938264481579)
# -------------------------------------------------------
# ((u'1827', u'John Quincy Adams'), (u'2000', u'William J. Clinton'), 0.74609958987894087)
# -------------------------------------------------------
# ((u'1878', u'Rutherford B. Hayes'), (u'2001', u'George W. Bush'), 0.74841269595188675)
# -------------------------------------------------------
# ((u'1856', u'Franklin Pierce'), (u'2001', u'George W. Bush'), 0.74910258505563609)
# -------------------------------------------------------
# ((u'1882', u'Chester A. Arthur'), (u'2000', u'William J. Clinton'), 0.75033526171182852)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1898', u'William McKinley'), 0.75099857402310988)
# -------------------------------------------------------
# ((u'1864', u'Abraham Lincoln'), (u'2001', u'George W. Bush'), 0.75184360327432265)
# -------------------------------------------------------
# ((u'1999', u'William J. Clinton'), (u'1883', u'Chester A. Arthur'), 0.75351288008824957)
# -------------------------------------------------------
# ((u'1994', u'William J. Clinton'), (u'1882', u'Chester A. Arthur'), 0.75473393097336672)
# -------------------------------------------------------
# ((u'2009', u'Barack Obama'), (u'1883', u'Chester A. Arthur'), 0.75476559160082746)
# -------------------------------------------------------
# ((u'1810', u'James Madison'), (u'2001', u'George W. Bush'), 0.75531712213537561)
# -------------------------------------------------------
# ((u'1883', u'Chester A. Arthur'), (u'1996', u'William J. Clinton'), 0.75538449237783334)
# -------------------------------------------------------
# ((u'1828', u'John Quincy Adams'), (u'2000', u'William J. Clinton'), 0.7557144947780815)
# -------------------------------------------------------
# ((u'1791', u'George Washington'), (u'2001', u'George W. Bush'), 0.75633139306079589)
# -------------------------------------------------------
# ((u'1826', u'John Quincy Adams'), (u'2001', u'George W. Bush'), 0.75646954064344352)
# -------------------------------------------------------
# ((u'1866', u'Andrew Johnson'), (u'2001', u'George W. Bush'), 0.75699893096424664)
# -------------------------------------------------------
# ((u'2002', u'George W. Bush'), (u'1882', u'Chester A. Arthur'), 0.75870962915811335)
# -------------------------------------------------------
# ((u'2002', u'George W. Bush'), (u'1883', u'Chester A. Arthur'), 0.75882728693220913)
# -------------------------------------------------------
# ((u'1880', u'Rutherford B. Hayes'), (u'2001', u'George W. Bush'), 0.75906221482445457)
# -------------------------------------------------------
# ((u'2001', u'George W. Bush'), (u'1900', u'William McKinley'), 0.75967379215194941)
# -------------------------------------------------------
# ((u'1997', u'William J. Clinton'), (u'1883', u'Chester A. Arthur'), 0.75970445513543006)
# -------------------------------------------------------
# ((u'1815', u'James Madison'), (u'2000', u'William J. Clinton'), 0.7607634146967247)
# -------------------------------------------------------
# ((u'1865', u'Andrew Johnson'), (u'2001', u'George W. Bush'), 0.76103876375306267)
# -------------------------------------------------------
# ((u'1827', u'John Quincy Adams'), (u'1994', u'William J. Clinton'), 0.76144081696429067)
# -------------------------------------------------------
# ((u'2009', u'Barack Obama'), (u'1882', u'Chester A. Arthur'), 0.76179899933767059)
# -------------------------------------------------------
# ((u'1999', u'William J. Clinton'), (u'1882', u'Chester A. Arthur'), 0.76208658786995398)
# -------------------------------------------------------
# ((u'1833', u'Andrew Jackson'), (u'2001', u'George W. Bush'), 0.76263012451031809)
# -------------------------------------------------------
# ((u'1882', u'Chester A. Arthur'), (u'1996', u'William J. Clinton'), 0.76272101160013139)
# -------------------------------------------------------
# ((u'1879', u'Rutherford B. Hayes'), (u'2001', u'George W. Bush'), 0.76297828971805215)
# -------------------------------------------------------
# ((u'1871', u'Ulysses S. Grant'), (u'2001', u'George W. Bush'), 0.76369553736485352)
# -------------------------------------------------------
# ((u'1827', u'John Quincy Adams'), (u'2009', u'Barack Obama'), 0.76432635342610633)
# -------------------------------------------------------
# ((u'1813', u'James Madison'), (u'2001', u'George W. Bush'), 0.7650625239608424)
# -------------------------------------------------------
# ((u'1873', u'Ulysses S. Grant'), (u'2001', u'George W. Bush'), 0.76522047527850801)
# -------------------------------------------------------
# ((u'1872', u'Ulysses S. Grant'), (u'2000', u'William J. Clinton'), 0.76534367497895572)
# -------------------------------------------------------
# ((u'1910', u'William Howard Taft'), (u'2001', u'George W. Bush'), 0.76550342143963113)
# -------------------------------------------------------
# ((u'1877', u'Rutherford B. Hayes'), (u'2001', u'George W. Bush'), 0.76600109049157838)
# -------------------------------------------------------
# ((u'1894', u'Grover Cleveland'), (u'2001', u'George W. Bush'), 0.7660671902926468)
# -------------------------------------------------------
# ((u'1827', u'John Quincy Adams'), (u'1999', u'William J. Clinton'), 0.76609259617420833)
# -------------------------------------------------------
